# %%
from functions import *

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline
plt.style.use('fivethirtyeight')
#sns.set()
#pd.options.display.max_columns = 100

# %% [markdown]
# # Read Master data

# %%
master_df = pd.read_csv('master_df_final.csv')
master_df.head()
# Out:
#    SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100002       1             0          202500.0    406597.5
# 1      100003       0             0          270000.0   1293502.5
# 2      100004       0             0           67500.0    135000.0
# 3      100006       0             0          135000.0    312682.5
# 4      100007       0             0          121500.0    513000.0
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 0      24700.5         351000.0                    0.018801        9461
# 1      35698.5        1129500.0                    0.003541       16765
# 2       6750.0         135000.0                    0.010032       19046
# 3      29686.5         297000.0                    0.008019       19005
# 4      21865.5         513000.0                    0.028663       19932
#
#    DAYS_EMPLOYED  ...  client_credit_SK_DPD_DEF_min_count  \
# 0           -637  ...                                 NaN
# ...

# %%
master_missing_values = missing_values_table(master_df)
master_missing_values
# Out:
# Your selected dataframe has 1678 columns.
# There are 1490 columns that have missing values.
#                                         Missing Values  \
# previous_RATE_INTEREST_PRIMARY_min              302902
# previous_RATE_INTEREST_PRIVILEGED_mean          302902
# previous_RATE_INTEREST_PRIMARY_max              302902
# previous_RATE_INTEREST_PRIMARY_mean             302902
# previous_RATE_INTEREST_PRIVILEGED_max           302902
# ...                                                ...
# CREDIT_TERM                                         12
# ANNUITY_INCOME_PERCENT                              12
# AMT_ANNUITY                                         12
# CNT_FAM_MEMBERS                                      2
# DAYS_LAST_PHONE_CHANGE                               1
#
#                                         % of Total Missing Values
# previous_RATE_INTEREST_PRIMARY_min                           98.5
# previous_RATE_INTEREST_PRIVILEGED_mean                       98.5
# ...

# %%
# remove columns with missing values > 90
master_df_clean = remove_missing_columns(master_df,threshold=80)
# Out:
# There are 69 columns with greater than 80% missing values.

# %%
master_missing_values = missing_values_table(master_df_clean)
master_missing_values
# Out:
# Your selected dataframe has 1609 columns.
# There are 1421 columns that have missing values.
#                                                    Missing Values  \
# bureau_AMT_ANNUITY_min                                     227502
# bureau_AMT_ANNUITY_max                                     227502
# bureau_AMT_ANNUITY_mean                                    227502
# client_credit_AMT_PAYMENT_CURRENT_min_sum                  220606
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_count_min          220606
# ...                                                           ...
# CREDIT_TERM                                                    12
# ANNUITY_INCOME_PERCENT                                         12
# AMT_ANNUITY                                                    12
# CNT_FAM_MEMBERS                                                 2
# DAYS_LAST_PHONE_CHANGE                                          1
#
#                                                    % of Total Missing Values
# ...

# %%
# free memory 
gc.enable()
del master_missing_values, master_df
gc.collect()

master_df_clean.to_csv('master_final_cleaned.csv', index=False)
# Out:
# 0
